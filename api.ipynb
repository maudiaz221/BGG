# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

def fetch_game_data(game_id):
    """Fetch game data for a given game ID."""
    url = f'https://boardgamegeek.com/xmlapi2/thing?id={game_id}&stats=1'
    response = requests.get(url)
    while response.status_code != 200:
        response = requests.get(url)  # Retry fetching until success
    return response.text

def parse_game_data(game_xml):
    """Parse XML data for a single game."""
    root = ET.fromstring(game_xml)
    game_info = {}
    for item in root.findall('item'):
        game_info['id'] = item.get('id')
        game_info['name'] = item.find('name').get('value')
        statistics = item.find('statistics')
        ratings = statistics.find('ratings')
        game_info['average_rating'] = ratings.find('average').get('value')
        game_info['rank'] = ratings.find('ranks/rank').get('value')
    return game_info

def main():
    game_ids = range(1, 301)  # First 500 game IDs
    games_data = []

    for game_id in game_ids:
        game_xml = fetch_game_data(game_id)
        game_data = parse_game_data(game_xml)
        games_data.append(game_data)
        print(f"Fetched and parsed game ID: {game_id}")

    df = pd.DataFrame(games_data)
    print(df.head())
    df.to_csv('bgg_games_data.csv', index=False)

if __name__ == '__main__':
    main()
# Out:
# Fetched and parsed game ID: 1
# Fetched and parsed game ID: 2
# Fetched and parsed game ID: 3
# Fetched and parsed game ID: 4
# Fetched and parsed game ID: 5
# Fetched and parsed game ID: 6
# Fetched and parsed game ID: 7
# Fetched and parsed game ID: 8
# Fetched and parsed game ID: 9
# Fetched and parsed game ID: 10
# Fetched and parsed game ID: 11
# Fetched and parsed game ID: 12
# Fetched and parsed game ID: 13
# Fetched and parsed game ID: 14
# Fetched and parsed game ID: 15
# Fetched and parsed game ID: 16
# Fetched and parsed game ID: 17
# Fetched and parsed game ID: 18
# Fetched and parsed game ID: 19
# Fetched and parsed game ID: 20
# Fetched and parsed game ID: 21
# Fetched and parsed game ID: 22
# Fetched and parsed game ID: 23
# Fetched and parsed game ID: 24
# Fetched and parsed game ID: 25
# Fetched and parsed game ID: 26
# Fetched and parsed game ID: 27
# Fetched and parsed game ID: 28
# Fetched and parsed game ID: 29
# Fetched and parsed game ID: 30
# Fetched and parsed game ID: 31
# Fetched and parsed game ID: 32
# Fetched and parsed game ID: 33
# Fetched and parsed game ID: 34
# Fetched and parsed game ID: 35
# Fetched and parsed game ID: 36
# Fetched and parsed game ID: 37
# Fetched and parsed game ID: 38
# Fetched and parsed game ID: 39
# Fetched and parsed game ID: 40
# Fetched and parsed game ID: 41
# Fetched and parsed game ID: 42
# Fetched and parsed game ID: 43
# Fetched and parsed game ID: 44
# Fetched and parsed game ID: 45
# Fetched and parsed game ID: 46
# Fetched and parsed game ID: 47
# Fetched and parsed game ID: 48
# Fetched and parsed game ID: 49
# Fetched and parsed game ID: 50
# Fetched and parsed game ID: 51
# Fetched and parsed game ID: 52
# Fetched and parsed game ID: 53
# Fetched and parsed game ID: 54
# Fetched and parsed game ID: 55
# Fetched and parsed game ID: 56
# Fetched and parsed game ID: 57
# Fetched and parsed game ID: 58
# Fetched and parsed game ID: 59
# Fetched and parsed game ID: 60
# Fetched and parsed game ID: 61
# Fetched and parsed game ID: 62
# Fetched and parsed game ID: 63
# Fetched and parsed game ID: 64
# Fetched and parsed game ID: 65
# Fetched and parsed game ID: 66
# Fetched and parsed game ID: 67
# Fetched and parsed game ID: 68
# Fetched and parsed game ID: 69
# Fetched and parsed game ID: 70
# Fetched and parsed game ID: 71
# Fetched and parsed game ID: 72
# Fetched and parsed game ID: 73
# Fetched and parsed game ID: 74
# Fetched and parsed game ID: 75
# Fetched and parsed game ID: 76
# Fetched and parsed game ID: 77
# Fetched and parsed game ID: 78
# Fetched and parsed game ID: 79
# Fetched and parsed game ID: 80
# Fetched and parsed game ID: 81
# Fetched and parsed game ID: 82
# Fetched and parsed game ID: 83
# Fetched and parsed game ID: 84
# Fetched and parsed game ID: 85
# Fetched and parsed game ID: 86
# Fetched and parsed game ID: 87
# Fetched and parsed game ID: 88
# Fetched and parsed game ID: 89
# Fetched and parsed game ID: 90
# Fetched and parsed game ID: 91
# Fetched and parsed game ID: 92
# Fetched and parsed game ID: 93
# Fetched and parsed game ID: 94
# Fetched and parsed game ID: 95
# Fetched and parsed game ID: 96
# Fetched and parsed game ID: 97
# Fetched and parsed game ID: 98
# Fetched and parsed game ID: 99
# Fetched and parsed game ID: 100
# Fetched and parsed game ID: 101
# Fetched and parsed game ID: 102
# Fetched and parsed game ID: 103
# Fetched and parsed game ID: 104
# Fetched and parsed game ID: 105
# Fetched and parsed game ID: 106
# Fetched and parsed game ID: 107
# Fetched and parsed game ID: 108
# Fetched and parsed game ID: 109
# Fetched and parsed game ID: 110
# Fetched and parsed game ID: 111
# Fetched and parsed game ID: 112
# Fetched and parsed game ID: 113
# Fetched and parsed game ID: 114
# Fetched and parsed game ID: 115
# Fetched and parsed game ID: 116
# Fetched and parsed game ID: 117
# Fetched and parsed game ID: 118
# Fetched and parsed game ID: 119
# Fetched and parsed game ID: 120
# Fetched and parsed game ID: 121
# Fetched and parsed game ID: 122
# Fetched and parsed game ID: 123
# Fetched and parsed game ID: 124
# Fetched and parsed game ID: 125
# Fetched and parsed game ID: 126
# Fetched and parsed game ID: 127
# Fetched and parsed game ID: 128
# Fetched and parsed game ID: 129
# Fetched and parsed game ID: 130
# Fetched and parsed game ID: 131
# Fetched and parsed game ID: 132
# Fetched and parsed game ID: 133
# Fetched and parsed game ID: 134
# Fetched and parsed game ID: 135
# Fetched and parsed game ID: 136
# Fetched and parsed game ID: 137
# Fetched and parsed game ID: 138
# Fetched and parsed game ID: 139
# Fetched and parsed game ID: 140
# Fetched and parsed game ID: 141
# Fetched and parsed game ID: 142
# Fetched and parsed game ID: 143
# Fetched and parsed game ID: 144
# Fetched and parsed game ID: 145
# Fetched and parsed game ID: 146
# Fetched and parsed game ID: 147
# Fetched and parsed game ID: 148
# Fetched and parsed game ID: 149
# Fetched and parsed game ID: 150
# Fetched and parsed game ID: 151
# Fetched and parsed game ID: 152
# Fetched and parsed game ID: 153
# Fetched and parsed game ID: 154
# Fetched and parsed game ID: 155
# Fetched and parsed game ID: 156
# Fetched and parsed game ID: 157
# Fetched and parsed game ID: 158
# Fetched and parsed game ID: 159
# Fetched and parsed game ID: 160
# Fetched and parsed game ID: 161
# Fetched and parsed game ID: 162
# Fetched and parsed game ID: 163
# Fetched and parsed game ID: 164
# Fetched and parsed game ID: 165
# Fetched and parsed game ID: 166
# Fetched and parsed game ID: 167
# Fetched and parsed game ID: 168
# Fetched and parsed game ID: 169
# Fetched and parsed game ID: 170
# Fetched and parsed game ID: 171
# Fetched and parsed game ID: 172
# Fetched and parsed game ID: 173
# Fetched and parsed game ID: 174
# Fetched and parsed game ID: 175
# Fetched and parsed game ID: 176
# Fetched and parsed game ID: 177
# Fetched and parsed game ID: 178
# Fetched and parsed game ID: 179
# Fetched and parsed game ID: 180
# Fetched and parsed game ID: 181
# Fetched and parsed game ID: 182
# Fetched and parsed game ID: 183
# Fetched and parsed game ID: 184
# Fetched and parsed game ID: 185
# Fetched and parsed game ID: 186
# Fetched and parsed game ID: 187
# Fetched and parsed game ID: 188
# Fetched and parsed game ID: 189
# Fetched and parsed game ID: 190
# Fetched and parsed game ID: 191
# Fetched and parsed game ID: 192
# Fetched and parsed game ID: 193
# Fetched and parsed game ID: 194
# Fetched and parsed game ID: 195
# Fetched and parsed game ID: 196
# Fetched and parsed game ID: 197
# Fetched and parsed game ID: 198
# Fetched and parsed game ID: 199
# Fetched and parsed game ID: 200
# Fetched and parsed game ID: 201
# Fetched and parsed game ID: 202
# Fetched and parsed game ID: 203
# Fetched and parsed game ID: 204
# Fetched and parsed game ID: 205
# Fetched and parsed game ID: 206
# Fetched and parsed game ID: 207
# Fetched and parsed game ID: 208
# Fetched and parsed game ID: 209
# Fetched and parsed game ID: 210
# Fetched and parsed game ID: 211
# Fetched and parsed game ID: 212
# Fetched and parsed game ID: 213
# Fetched and parsed game ID: 214
# Fetched and parsed game ID: 215
# Fetched and parsed game ID: 216
# Fetched and parsed game ID: 217
# Fetched and parsed game ID: 218
# Fetched and parsed game ID: 219
# Fetched and parsed game ID: 220
# Fetched and parsed game ID: 221
# Fetched and parsed game ID: 222
# Fetched and parsed game ID: 223
# Fetched and parsed game ID: 224
# Fetched and parsed game ID: 225
# Fetched and parsed game ID: 226
# Fetched and parsed game ID: 227
# Fetched and parsed game ID: 228
# Fetched and parsed game ID: 229
# Fetched and parsed game ID: 230
# Fetched and parsed game ID: 231
# Fetched and parsed game ID: 232
# Fetched and parsed game ID: 233
# Fetched and parsed game ID: 234
# Fetched and parsed game ID: 235
# Fetched and parsed game ID: 236
# Fetched and parsed game ID: 237
# Fetched and parsed game ID: 238
# Fetched and parsed game ID: 239
# Fetched and parsed game ID: 240
# Fetched and parsed game ID: 241
# Fetched and parsed game ID: 242
# Fetched and parsed game ID: 243
# Fetched and parsed game ID: 244
# Fetched and parsed game ID: 245
# Fetched and parsed game ID: 246
# Fetched and parsed game ID: 247
# Fetched and parsed game ID: 248
# Fetched and parsed game ID: 249
# Fetched and parsed game ID: 250
# Fetched and parsed game ID: 251
# Fetched and parsed game ID: 252
# Fetched and parsed game ID: 253
# Fetched and parsed game ID: 254
# Fetched and parsed game ID: 255
# Fetched and parsed game ID: 256
# Fetched and parsed game ID: 257
# Fetched and parsed game ID: 258
# Fetched and parsed game ID: 259
# Fetched and parsed game ID: 260
# Fetched and parsed game ID: 261
# Fetched and parsed game ID: 262
# Fetched and parsed game ID: 263
# Fetched and parsed game ID: 264
# Fetched and parsed game ID: 265
# Fetched and parsed game ID: 266
# Fetched and parsed game ID: 267
# Fetched and parsed game ID: 268
# Fetched and parsed game ID: 269
# Fetched and parsed game ID: 270
# Fetched and parsed game ID: 271
# Fetched and parsed game ID: 272
# Fetched and parsed game ID: 273
# Fetched and parsed game ID: 274
# Fetched and parsed game ID: 275
# Fetched and parsed game ID: 276
# Fetched and parsed game ID: 277
# Fetched and parsed game ID: 278
# Fetched and parsed game ID: 279
# Fetched and parsed game ID: 280
# Fetched and parsed game ID: 281
# Fetched and parsed game ID: 282
# Fetched and parsed game ID: 283
# Fetched and parsed game ID: 284
# Fetched and parsed game ID: 285
# Fetched and parsed game ID: 286
# Fetched and parsed game ID: 287
# Fetched and parsed game ID: 288
# Fetched and parsed game ID: 289
# Fetched and parsed game ID: 290
# Fetched and parsed game ID: 291
# Fetched and parsed game ID: 292
# Fetched and parsed game ID: 293
# Fetched and parsed game ID: 294
# Fetched and parsed game ID: 295
# Fetched and parsed game ID: 296
# Fetched and parsed game ID: 297
# Fetched and parsed game ID: 298
# Fetched and parsed game ID: 299
# Fetched and parsed game ID: 300
#   id            name average_rating  rank
# 0  1      Die Macher        7.59453   424
# 1  2    Dragonmaster        6.64233  4969
# 2  3         Samurai        7.46946   269
# 3  4  Tal der Könige        6.60045  6646
# 4  5         Acquire        7.34256   343

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET

def fetch_game_data(game_id):
    """Fetch game data for a given game ID."""
    url = f'https://boardgamegeek.com/xmlapi2/thing?id={game_id}&stats=1'
    response = requests.get(url)
    while response.status_code != 200:
        response = requests.get(url)  # Retry fetching until success
    return response.text

def parse_game_data(game_xml):
    """Parse XML data for a single game."""
    root = ET.fromstring(game_xml)
    game_info = {}
    for item in root.findall('item'):
        game_info['id'] = item.get('id')
        game_info['name'] = item.find('name').get('value')
        statistics = item.find('statistics')
        ratings = statistics.find('ratings')
        game_info['average_rating'] = ratings.find('average').get('value')
        game_info['rank'] = ratings.find('ranks/rank').get('value')
        
        # Additional fields
        game_info['min_players'] = item.find('minplayers').get('value')
        game_info['max_players'] = item.find('maxplayers').get('value')
        game_info['playing_time'] = item.find('playingtime').get('value')
        game_info['min_playtime'] = item.find('minplaytime').get('value')
        game_info['max_playtime'] = item.find('maxplaytime').get('value')
        
        # Publishers
        publishers = [link.get('value') for link in item.findall("link") if link.get('type') == 'boardgamepublisher']
        game_info['publishers'] = publishers

        # Categories
        categories = [link.get('value') for link in item.findall("link") if link.get('type') == 'boardgamecategory']
        game_info['categories'] = categories

    return game_info

def main():
    game_ids = range(1, 301)  # First 300 game IDs
    games_data = []

    for game_id in game_ids:
        game_xml = fetch_game_data(game_id)
        game_data = parse_game_data(game_xml)
        games_data.append(game_data)
        print(f"Fetched and parsed game ID: {game_id}")

    df = pd.DataFrame(games_data)
    print(df.head())
    df.to_csv('bgg_games_data.csv', index=False)

if __name__ == '__main__':
    main()
# Out:
# Fetched and parsed game ID: 1
# Fetched and parsed game ID: 2
# Fetched and parsed game ID: 3
# Fetched and parsed game ID: 4
# Fetched and parsed game ID: 5
# Fetched and parsed game ID: 6
# Fetched and parsed game ID: 7
# Fetched and parsed game ID: 8
# Fetched and parsed game ID: 9
# Fetched and parsed game ID: 10
# Fetched and parsed game ID: 11
# Fetched and parsed game ID: 12
# Fetched and parsed game ID: 13
# Fetched and parsed game ID: 14
# Fetched and parsed game ID: 15
# Fetched and parsed game ID: 16
# Fetched and parsed game ID: 17
# Fetched and parsed game ID: 18
# Fetched and parsed game ID: 19
# Fetched and parsed game ID: 20
# Fetched and parsed game ID: 21
# Fetched and parsed game ID: 22
# Fetched and parsed game ID: 23
# Fetched and parsed game ID: 24
# Fetched and parsed game ID: 25
# Fetched and parsed game ID: 26
# Fetched and parsed game ID: 27
# Fetched and parsed game ID: 28
# Fetched and parsed game ID: 29
# Fetched and parsed game ID: 30
# Fetched and parsed game ID: 31
# Fetched and parsed game ID: 32
# Fetched and parsed game ID: 33
# Fetched and parsed game ID: 34
# Fetched and parsed game ID: 35
# Fetched and parsed game ID: 36
# Fetched and parsed game ID: 37
# Fetched and parsed game ID: 38
# Fetched and parsed game ID: 39
# Fetched and parsed game ID: 40
# Fetched and parsed game ID: 41
# Fetched and parsed game ID: 42
# Fetched and parsed game ID: 43
# Fetched and parsed game ID: 44
# Fetched and parsed game ID: 45
# Fetched and parsed game ID: 46
# Fetched and parsed game ID: 47
# Fetched and parsed game ID: 48
# Fetched and parsed game ID: 49
# Fetched and parsed game ID: 50
# Fetched and parsed game ID: 51
# Fetched and parsed game ID: 52
# Fetched and parsed game ID: 53
# Fetched and parsed game ID: 54
# Fetched and parsed game ID: 55
# Fetched and parsed game ID: 56
# Fetched and parsed game ID: 57
# Fetched and parsed game ID: 58
# Fetched and parsed game ID: 59
# Fetched and parsed game ID: 60
# Fetched and parsed game ID: 61
# Fetched and parsed game ID: 62
# Fetched and parsed game ID: 63
# Fetched and parsed game ID: 64
# Fetched and parsed game ID: 65
# Fetched and parsed game ID: 66
# Fetched and parsed game ID: 67
# Fetched and parsed game ID: 68
# Fetched and parsed game ID: 69
# Fetched and parsed game ID: 70
# Fetched and parsed game ID: 71
# Fetched and parsed game ID: 72
# Fetched and parsed game ID: 73
# Fetched and parsed game ID: 74
# Fetched and parsed game ID: 75
# Fetched and parsed game ID: 76
# Fetched and parsed game ID: 77
# Fetched and parsed game ID: 78
# Fetched and parsed game ID: 79
# Fetched and parsed game ID: 80
# Fetched and parsed game ID: 81
# Fetched and parsed game ID: 82
# Fetched and parsed game ID: 83
# Fetched and parsed game ID: 84
# Fetched and parsed game ID: 85
# Fetched and parsed game ID: 86
# Fetched and parsed game ID: 87
# Fetched and parsed game ID: 88
# Fetched and parsed game ID: 89
# Fetched and parsed game ID: 90
# Fetched and parsed game ID: 91
# Fetched and parsed game ID: 92
# Fetched and parsed game ID: 93
# Fetched and parsed game ID: 94
# Fetched and parsed game ID: 95
# Fetched and parsed game ID: 96
# Fetched and parsed game ID: 97
# Fetched and parsed game ID: 98
# Fetched and parsed game ID: 99
# Fetched and parsed game ID: 100
# Fetched and parsed game ID: 101
# Fetched and parsed game ID: 102
# Fetched and parsed game ID: 103
# Fetched and parsed game ID: 104
# Fetched and parsed game ID: 105
# Fetched and parsed game ID: 106
# Fetched and parsed game ID: 107
# Fetched and parsed game ID: 108
# Fetched and parsed game ID: 109
# Fetched and parsed game ID: 110
# Fetched and parsed game ID: 111
# Fetched and parsed game ID: 112
# Fetched and parsed game ID: 113
# Fetched and parsed game ID: 114
# Fetched and parsed game ID: 115
# Fetched and parsed game ID: 116
# Fetched and parsed game ID: 117
# Fetched and parsed game ID: 118
# Fetched and parsed game ID: 119
# Fetched and parsed game ID: 120
# Fetched and parsed game ID: 121
# Fetched and parsed game ID: 122
# Fetched and parsed game ID: 123
# Fetched and parsed game ID: 124
# Fetched and parsed game ID: 125
# Fetched and parsed game ID: 126
# Fetched and parsed game ID: 127
# Fetched and parsed game ID: 128
# Fetched and parsed game ID: 129
# Fetched and parsed game ID: 130
# Fetched and parsed game ID: 131
# Fetched and parsed game ID: 132
# Fetched and parsed game ID: 133
# Fetched and parsed game ID: 134
# Fetched and parsed game ID: 135
# Fetched and parsed game ID: 136
# Fetched and parsed game ID: 137
# Fetched and parsed game ID: 138
# Fetched and parsed game ID: 139
# Fetched and parsed game ID: 140
# Fetched and parsed game ID: 141
# Fetched and parsed game ID: 142
# Fetched and parsed game ID: 143
# Fetched and parsed game ID: 144
# Fetched and parsed game ID: 145
# Fetched and parsed game ID: 146
# Fetched and parsed game ID: 147
# Fetched and parsed game ID: 148
# Fetched and parsed game ID: 149
# Fetched and parsed game ID: 150
# Fetched and parsed game ID: 151
# Fetched and parsed game ID: 152
# Fetched and parsed game ID: 153
# Fetched and parsed game ID: 154
# Fetched and parsed game ID: 155
# Fetched and parsed game ID: 156
# Fetched and parsed game ID: 157
# Fetched and parsed game ID: 158
# Fetched and parsed game ID: 159
# Fetched and parsed game ID: 160
# Fetched and parsed game ID: 161
# Fetched and parsed game ID: 162
# Fetched and parsed game ID: 163
# Fetched and parsed game ID: 164
# Fetched and parsed game ID: 165
# Fetched and parsed game ID: 166
# Fetched and parsed game ID: 167
# Fetched and parsed game ID: 168
# Fetched and parsed game ID: 169
# Fetched and parsed game ID: 170
# Fetched and parsed game ID: 171
# Fetched and parsed game ID: 172
# Fetched and parsed game ID: 173
# Fetched and parsed game ID: 174
# Fetched and parsed game ID: 175
# Fetched and parsed game ID: 176
# Fetched and parsed game ID: 177
# Fetched and parsed game ID: 178
# Fetched and parsed game ID: 179
# Fetched and parsed game ID: 180
# Fetched and parsed game ID: 181
# Fetched and parsed game ID: 182
# Fetched and parsed game ID: 183
# Fetched and parsed game ID: 184
# Fetched and parsed game ID: 185
# Fetched and parsed game ID: 186
# Fetched and parsed game ID: 187
# Fetched and parsed game ID: 188
# Fetched and parsed game ID: 189
# Fetched and parsed game ID: 190
# Fetched and parsed game ID: 191
# Fetched and parsed game ID: 192
# Fetched and parsed game ID: 193
# Fetched and parsed game ID: 194
# Fetched and parsed game ID: 195
# Fetched and parsed game ID: 196
# Fetched and parsed game ID: 197
# Fetched and parsed game ID: 198
# Fetched and parsed game ID: 199
# Fetched and parsed game ID: 200
# Fetched and parsed game ID: 201
# Fetched and parsed game ID: 202
# Fetched and parsed game ID: 203
# Fetched and parsed game ID: 204
# Fetched and parsed game ID: 205
# Fetched and parsed game ID: 206
# Fetched and parsed game ID: 207
# Fetched and parsed game ID: 208
# Fetched and parsed game ID: 209
# Fetched and parsed game ID: 210
# Fetched and parsed game ID: 211
# Fetched and parsed game ID: 212
# Fetched and parsed game ID: 213
# Fetched and parsed game ID: 214
# Fetched and parsed game ID: 215
# Fetched and parsed game ID: 216
# Fetched and parsed game ID: 217
# Fetched and parsed game ID: 218
# Fetched and parsed game ID: 219
# Fetched and parsed game ID: 220
# Fetched and parsed game ID: 221
# Fetched and parsed game ID: 222
# Fetched and parsed game ID: 223
# Fetched and parsed game ID: 224
# Fetched and parsed game ID: 225
# Fetched and parsed game ID: 226
# Fetched and parsed game ID: 227
# Fetched and parsed game ID: 228
# Fetched and parsed game ID: 229
# Fetched and parsed game ID: 230
# Fetched and parsed game ID: 231
# Fetched and parsed game ID: 232
# Fetched and parsed game ID: 233
# Fetched and parsed game ID: 234
# Fetched and parsed game ID: 235
# Fetched and parsed game ID: 236
# Fetched and parsed game ID: 237
# Fetched and parsed game ID: 238
# Fetched and parsed game ID: 239
# Fetched and parsed game ID: 240
# Fetched and parsed game ID: 241
# Fetched and parsed game ID: 242
# Fetched and parsed game ID: 243
# Fetched and parsed game ID: 244
# Fetched and parsed game ID: 245
# Fetched and parsed game ID: 246
# Fetched and parsed game ID: 247
# Fetched and parsed game ID: 248
# Fetched and parsed game ID: 249
# Fetched and parsed game ID: 250
# Fetched and parsed game ID: 251
# Fetched and parsed game ID: 252
# Fetched and parsed game ID: 253
# Fetched and parsed game ID: 254
# Fetched and parsed game ID: 255
# Fetched and parsed game ID: 256
# Fetched and parsed game ID: 257
# Fetched and parsed game ID: 258
# Fetched and parsed game ID: 259
# Fetched and parsed game ID: 260
# Fetched and parsed game ID: 261
# Fetched and parsed game ID: 262
# Fetched and parsed game ID: 263
# Fetched and parsed game ID: 264
# Fetched and parsed game ID: 265
# Fetched and parsed game ID: 266
# Fetched and parsed game ID: 267
# Fetched and parsed game ID: 268
# Fetched and parsed game ID: 269
# Fetched and parsed game ID: 270
# Fetched and parsed game ID: 271
# Fetched and parsed game ID: 272
# Fetched and parsed game ID: 273
# Fetched and parsed game ID: 274
# Fetched and parsed game ID: 275
# Fetched and parsed game ID: 276
# Fetched and parsed game ID: 277
# Fetched and parsed game ID: 278
# Fetched and parsed game ID: 279
# Fetched and parsed game ID: 280
# Fetched and parsed game ID: 281
# Fetched and parsed game ID: 282
# Fetched and parsed game ID: 283
# Fetched and parsed game ID: 284
# Fetched and parsed game ID: 285
# Fetched and parsed game ID: 286
# Fetched and parsed game ID: 287
# Fetched and parsed game ID: 288
# Fetched and parsed game ID: 289
# Fetched and parsed game ID: 290
# Fetched and parsed game ID: 291
# Fetched and parsed game ID: 292
# Fetched and parsed game ID: 293
# Fetched and parsed game ID: 294
# Fetched and parsed game ID: 295
# Fetched and parsed game ID: 296
# Fetched and parsed game ID: 297
# Fetched and parsed game ID: 298
# Fetched and parsed game ID: 299
# Fetched and parsed game ID: 300
#   id            name average_rating  rank min_players max_players  \
# 0  1      Die Macher        7.59453   424           3           5
# 1  2    Dragonmaster        6.64233  4969           3           4
# 2  3         Samurai        7.46946   269           2           4
# 3  4  Tal der Könige        6.60045  6646           2           4
# 4  5         Acquire        7.34256   343           2           6
#
#   playing_time min_playtime max_playtime  \
# 0          240          240          240
# 1           30           30           30
# 2           60           30           60
# 3           60           60           60
# 4           90           90           90
#
#                                           publishers  \
# 0  [Hans im Glück, Moskito Spiele, Ediciones MasQ...
# 1          [E. S. Lowe Company Inc., Milton Bradley]
# 2  [Fantasy Flight Games, Hans im Glück, 999 Game...
# 3                                           [KOSMOS]
# 4  [3M, The Avalon Hill Game Co, Arclight Games, ...
#
#                            categories
# 0  [Economic, Negotiation, Political]
# 1                [Card Game, Fantasy]
# 2       [Abstract Strategy, Medieval]
# 3                           [Ancient]
# 4      [Economic, Territory Building]

# %% [markdown]
# ## Users

# %%
import time

# %%
def fetch_xml(url):
    """Utility function to fetch XML data from a URL."""
    response = requests.get(url)
    while response.status_code != 200:
        # Adding a brief pause to respect rate limits and avoid being blocked
        time.sleep(1)
        response = requests.get(url)
    return response.text

def extract_usernames_from_comments(game_id, max_usernames=50):
    """Extract usernames from comments of a specified game, limited by max_usernames."""
    usernames = []
    page = 1
    while len(usernames) < max_usernames:
        url = f'https://boardgamegeek.com/xmlapi2/thing?id={game_id}&ratingcomments=1&page={page}'
        xml_data = fetch_xml(url)
        root = ET.fromstring(xml_data)
        comments = root.findall('.//comment')
        if not comments:
            break  # Exit if no more comments are available
        for comment in comments:
            if len(usernames) >= max_usernames:
                break
            usernames.append(comment.get('username'))
        page += 1
    return usernames

def fetch_user_data(username):
    """Fetch detailed user data for a given username."""
    url = f'https://boardgamegeek.com/xmlapi2/user?name={username}'
    xml_data = fetch_xml(url)
    root = ET.fromstring(xml_data)
    user_info = {'username': username}
    user_info['id'] = root.find('user').get('id') if root.find('user') is not None else None
    return user_info

def save_usernames_to_txt(usernames, filename='usernames.txt'):
    """Save usernames to a text file."""
    with open(filename, 'w') as file:
        for username in usernames:
            file.write(f'{username}\n')
    print(f'Usernames saved to {filename}')

def main():
    # Example to fetch comments from game ID 13 (Catan)
    usernames = extract_usernames_from_comments(13)
    save_usernames_to_txt(usernames)  # Save usernames to a .txt file
    users_data = [fetch_user_data(username) for username in usernames[:50]]  # Fetch data for 50 usernames

    df = pd.DataFrame(users_data)
    print(df.head())
    df.to_csv('bgg_users_data.csv', index=False)

if __name__ == '__main__':
    main()
# Out:
# Usernames saved to usernames.txt
#       username    id
# 0   sidehacker  None
# 1  Varthlokkur  None
# 2   dougthonus  None
# 3       cypar7  None
# 4      ssmooth  None

# %%
import requests
import pandas as pd
import xml.etree.ElementTree as ET
import time

def fetch_xml(url):
    """Utility function to fetch XML data from a URL."""
    response = requests.get(url)
    while response.status_code != 200:
        # Adding a brief pause to respect rate limits and avoid being blocked
        time.sleep(1)
        response = requests.get(url)
    return response.text

def extract_usernames_from_comments(game_id, max_usernames=50):
    """Extract usernames from comments of a specified game, limited by max_usernames."""
    usernames = []
    page = 1
    while len(usernames) < max_usernames:
        url = f'https://boardgamegeek.com/xmlapi2/thing?id={game_id}&ratingcomments=1&page={page}'
        xml_data = fetch_xml(url)
        root = ET.fromstring(xml_data)
        comments = root.findall('.//comment')
        if not comments:
            break  # Exit if no more comments are available
        for comment in comments:
            if len(usernames) >= max_usernames:
                break
            usernames.append(comment.get('username'))
        page += 1
    return usernames

def fetch_user_data(username):
    """Fetch detailed user data for a given username, including their game collection."""
    url = f'https://boardgamegeek.com/xmlapi2/user?name={username}&buddies=1&hot=1&top=1'
    user_xml = fetch_xml(url)
    user_root = ET.fromstring(user_xml)

    user_info = {
        'username': username,
        'id': user_root.find('user').get('id') if user_root.find('user') is not None else None,
        'games': []
    }

    # Fetching the user's game collection
    collection_url = f'https://boardgamegeek.com/xmlapi2/collection?username={username}&own=1'
    collection_xml = fetch_xml(collection_url)
    collection_root = ET.fromstring(collection_xml)
    for item in collection_root.findall('item'):
        game_name = item.find('name').text
        user_info['games'].append(game_name)

    return user_info

def save_usernames_to_txt(usernames, filename='usernames.txt'):
    """Save usernames to a text file."""
    with open(filename, 'w') as file:
        for username in usernames:
            file.write(f'{username}\n')
    print(f'Usernames saved to {filename}')

def main():
    # Example to fetch comments from game ID 13 (Catan)
    usernames = extract_usernames_from_comments(13)
    save_usernames_to_txt(usernames)  # Save usernames to a .txt file
    users_data = [fetch_user_data(username) for username in usernames[:50]]  # Fetch data for 50 usernames

    df = pd.DataFrame(users_data)
    print(df.head())
    df.to_csv('bgg_users_data.csv', index=False)

if __name__ == '__main__':
    main()
# Out:
# Usernames saved to usernames.txt
#       username    id                                              games
# 0   sidehacker  None  [7 Wonders, 7 Wonders: Babel, Above and Below,...
# 1  Varthlokkur  None  [Acquire, Advanced Civilization, Agricola, Agr...
# 2   dougthonus  None  [Acquire, CATAN, Catan Card Game, CATAN: Citie...
# 3       cypar7  None  [Agricola, Bad Grandmas, Beer & Bread, The Big...
# 4      ssmooth  None  [6 Nimmt!, Abalone, Acquire, Advance to Boardw...
